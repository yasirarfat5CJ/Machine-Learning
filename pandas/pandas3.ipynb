# %%
import pandas as pd

obesity_data = pd.read_csv('obseity_prediction.csv')
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
## updation or we say modification
obesity_data.loc[0,'Age']=30

# %%
obesity_data.loc[0,'Age']
# Out:
# 30.0

# %%
obesity_data.loc[:,'SMOKE']='yes'

# %%
obesity_data['SMOKE']
# Out:
# 0       yes
# 1       yes
# 2       yes
# 3       yes
# 4       yes
#        ...
# 2106    yes
# 2107    yes
# 2108    yes
# 2109    yes
# 2110    yes
# Name: SMOKE, Length: 2111, dtype: object

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  30.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data.loc[[2,3],'Height']=2.0

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  30.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    2.00    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    2.00    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data.iloc[1,4]='no'

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  30.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0             no   no   3.0  3.0  Sometimes
# 2    Male  23.0    2.00    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    2.00    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data.at[2,'Gender']='Female'

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  30.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0             no   no   3.0  3.0  Sometimes
# 2  Female  23.0    2.00    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    2.00    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data.iat[2,0]='Male'

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  30.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0             no   no   3.0  3.0  Sometimes
# 2    Male  male    2.00    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    2.00    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data.iat[2,2]=30

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  30.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0             no   no   3.0  3.0  Sometimes
# 2    Male  male   30.00    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    2.00    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data.iat[2,1]=30

# %%
obesity_data.iat[2,2]=1.4

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  30.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  30.0    1.40    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data['SMOKE']='may be '

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  30.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0             no   no   3.0  3.0  Sometimes
# 2    Male    30    1.40    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    2.00    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#      SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  may be    2.0   no  0.0  1.0          no  Public_Transportation
# 1  may be    3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  may be    2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  may be    2.0   no  2.0  0.0  Frequently                Walking
# 4  may be    2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# ...

# %%
def increment_age(x):
    return x+5
obesity_data['Age']=obesity_data['Age'].apply(increment_age)
obesity_data['Age']
# Out:
# 0       26.000000
# 1       26.000000
# 2       28.000000
# 3       32.000000
# 4       27.000000
#           ...
# 2106    25.976842
# 2107    26.982942
# 2108    27.524036
# 2109    29.361936
# 2110    28.664709
# Name: Age, Length: 2111, dtype: float64

# %%
obesity_data['Age']=obesity_data['Age'].apply(lambda x : x-5)
obesity_data['Age']
# Out:
# 0       16.000000
# 1       16.000000
# 2       18.000000
# 3       22.000000
# 4       17.000000
#           ...
# 2106    15.976842
# 2107    16.982942
# 2108    17.524036
# 2109    19.361936
# 2110    18.664709
# Name: Age, Length: 2111, dtype: float64

# %%
obesity_data['Age_Category']=obesity_data['Age'].apply(lambda x: 'very young' if x<20 else 'Not so young')
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  30.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  30.0    1.40    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity  Age_Category
# 0        Normal_Weight  Not so young
# 1        Normal_Weight  Not so young
# ...

# %%
obesity_data.insert(2,'BMI',20)
obesity_data.head()
# Out:
#    Gender   Age  BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  30.0   20    1.62    64.0            yes   no   2.0  3.0
# 1  Female  21.0   20    1.52    56.0            yes   no   3.0  3.0
# 2    Male  30.0   20    1.40    77.0            yes   no   2.0  3.0
# 3    Male  27.0   20    1.80    87.0             no   no   3.0  3.0
# 4    Male  22.0   20    1.78    89.8             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity  Age_Category
# 0        Normal_Weight  Not so young
# ...

# %%
obesity_data.drop(columns='BMI')
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  16.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  16.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  18.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  22.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  17.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  15.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  16.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  17.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  19.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  18.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
obesity_data.head()
# Out:
#    Gender   Age  BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  16.0   20    1.62    64.0            yes   no   2.0  3.0
# 1  Female  16.0   20    1.52    56.0            yes   no   3.0  3.0
# 2    Male  18.0   20    1.80    77.0            yes   no   2.0  3.0
# 3    Male  22.0   20    1.80    87.0             no   no   3.0  3.0
# 4    Male  17.0   20    1.78    89.8             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity  Age_Category
# 0        Normal_Weight    very young
# ...

# %%
obesity_data.drop(columns='BMI',inplace=True)

# %%
obesity_data.head()
# Out:
#    Gender   Age        BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  16.0  24.386526    1.62    64.0            yes   no   2.0  3.0
# 1  Female  16.0  24.238227    1.52    56.0            yes   no   3.0  3.0
# 2    Male  18.0  23.765432    1.80    77.0            yes   no   2.0  3.0
# 3    Male  22.0  26.851852    1.80    87.0             no   no   3.0  3.0
# 4    Male  17.0  28.342381    1.78    89.8             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity  Age_Category
# ...

# %%
obesity_data.insert(2,'BMI',obesity_data['Weight']/obesity_data['Height']**2)
obesity_data.head()
# Out:
#    Gender   Age        BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  21.0  24.386526    1.62    64.0            yes   no   2.0  3.0
# 1  Female  21.0  24.238227    1.52    56.0            yes   no   3.0  3.0
# 2    Male  23.0  23.765432    1.80    77.0            yes   no   2.0  3.0
# 3    Male  27.0  26.851852    1.80    87.0             no   no   3.0  3.0
# 4    Male  22.0  28.342381    1.78    89.8             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# ...

# %%
obesity_data.rename(columns={"BMI":'bmi'},inplace=True)

# %%
obesity_data.head()
# Out:
#    Gender   Age        bmi  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  21.0  24.386526    1.62    64.0            yes   no   2.0  3.0
# 1  Female  21.0  24.238227    1.52    56.0            yes   no   3.0  3.0
# 2    Male  23.0  23.765432    1.80    77.0            yes   no   2.0  3.0
# 3    Male  27.0  26.851852    1.80    87.0             no   no   3.0  3.0
# 4    Male  22.0  28.342381    1.78    89.8             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# ...

# %%
obesity_data.drop(columns='bmi',inplace=True)

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...
